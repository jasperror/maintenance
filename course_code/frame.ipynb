# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
index_names = ['engine', 'cycle']
# Operational conditions: altitude, mach_number and throttle_resolver_angle
operational_condition_names = ['altitude', 'TRA', 'mach_nr']
sensor_names = ['T2', # total temperature at fan inlet
                'T24',# total temperature at LPC outlet
                'T30', # total temperature at HPC outlet
                'T50', # total temperature at LPT outlet
                'P2', # Pressure at fan inlet
                'P15', #Total pressure in bypass-duct
                'P30', #Total pressure at HPC outlet
                'Nf', #Physical fan speed rpm
                'Nc', #Physical core speed rpm
                'epr', #Engine pressure ratio (P50/P2)
                'Ps30', #Static pressure at HPC outlet
                'phi', #Ratio offuel flow to Ps30
                'NRf', #Corrected fan speed
                'NRc', #Corrected core speed
                'BPR', #Bypass Ratio
                'farB', #Burner fuel-air ratio
                'htBleed', #Bleed Enthalpy
                'Nf_dmd', # Demanded fan speed rpm
                'PCNfR_dmd', #Demanded corrected fan speed rpm
                'W31', #HPT coolant bleed lbm/s
                'W32', #LPT coolant bleed
                ]
# options to visualize the datadrame
pd.set_option('display.width', 100)
col_names = index_names + operational_condition_names + sensor_names
df = pd.read_csv('data/train_FD001.txt', sep=' ', lineterminator='\n', header=0, index_col=False, names=col_names)
print(df.columns)
print(df.head(5))
# Out:
# Index(['engine', 'cycle', 'altitude', 'TRA', 'mach_nr', 'T2', 'T24', 'T30', 'T50', 'P2', 'P15',
#        'P30', 'Nf', 'Nc', 'epr', 'Ps30', 'phi', 'NRf', 'NRc', 'BPR', 'farB', 'htBleed', 'Nf_dmd',
#        'PCNfR_dmd', 'W31', 'W32'],
#       dtype='object')
#    engine  cycle  altitude     TRA  mach_nr      T2     T24      T30      T50     P2  ...     phi  \
# 0       1      2    0.0019 -0.0003    100.0  518.67  642.15  1591.82  1403.14  14.62  ...  522.28
# 1       1      3   -0.0043  0.0003    100.0  518.67  642.35  1587.99  1404.20  14.62  ...  522.42
# 2       1      4    0.0007  0.0000    100.0  518.67  642.35  1582.79  1401.87  14.62  ...  522.86
# 3       1      5   -0.0019 -0.0002    100.0  518.67  642.37  1582.85  1406.22  14.62  ...  522.19
# 4       1      6   -0.0043 -0.0001    100.0  518.67  642.10  1584.47  1398.37  14.62  ...  521.68
#
#        NRf      NRc     BPR  farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32
# 0  2388.07  8131.49  8.4318  0.03      392    2388      100.0  39.00  23.4236
# 1  2388.03  8133.23  8.4178  0.03      390    2388      100.0  38.95  23.3442
# 2  2388.08  8133.83  8.3682  0.03      392    2388      100.0  38.88  23.3739
# 3  2388.04  8133.80  8.4294  0.03      393    2388      100.0  38.90  23.4044
# 4  2388.03  8132.85  8.4108  0.03      391    2388      100.0  38.98  23.3669
#
# [5 rows x 26 columns]

# %%
# condition monitoring signals
engine_id = 3
v2_engine1 = df.loc[df['engine'] == engine_id, 'P30']
time_engine1 = df.loc[df['engine'] == engine_id, 'cycle']
plt.scatter(time_engine1,v2_engine1)
plt.xlabel('Time (cycles)')
plt.ylabel('P30')
plt.title('Engine' + str(engine_id))
# Out:
# Text(0.5, 1.0, 'Engine3')

# %%
# operational conditions
op_condition_name = 'mach_nr'
op_engine1 = df.loc[df.engine == 1, op_condition_name]
plt.scatter(range(len(op_engine1)), op_engine1)
plt.xlabel('Time (cycles)')
plt.title('Engine 1')
plt.ylabel('Operational Condition ' + op_condition_name)
# Out:
# Text(0, 0.5, 'Operational Condition mach_nr')

# %%
# plot all signals of one engine
figure, axis = plt.subplots(7, 3)

for i in range(21):
    feature_name = sensor_names[i]
    engine_id = 2
    signal = df.loc[df.engine == engine_id, feature_name]
    axis[i % 7, i % 3].scatter(range(len(signal)), signal)
    axis[i % 7, i % 3].set_ylabel(feature_name)

# %%
#correlation map of the dataset
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')# coolwarm
# check https://towardsdatascience.com/better-heatmaps-and-correlation-matrix-plots-in-python-41445d0f2bec
# Out:
# /Users/marciabaptista/PycharmProjects/MMA_2024/venv/lib/python3.11/site-packages/pandas/io/formats/style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Users/marciabaptista/PycharmProjects/MMA_2024/venv/lib/python3.11/site-packages/pandas/io/formats/style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_688d6_row0_col0, #T_688d6_row1_col1, #T_688d6_row2_col2, #T_688d6_row3_col3, #T_688d6_row6_col6, #T_688d6_row7_col7, #T_688d6_row8_col8, #T_688d6_row10_col10, #T_688d6_row11_col11, #T_688d6_row12_col12, #T_688d6_row13_col13, #T_688d6_row15_col15, #T_688d6_row16_col16, #T_688d6_row17_col17, #T_688d6_row18_col18, #T_688d6_row19_col19, #T_688d6_row21_col21, #T_688d6_row24_col24, #T_688d6_row25_col25 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_688d6_row0_col1, #T_688d6_row0_col6, #T_688d6_row0_col25, #T_688d6_row2_col25, #T_688d6_row3_col24 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_688d6_row0_col2, #T_688d6_row11_col3, #T_688d6_row11_col10, #T_688d6_row15_col11, #T_688d6_row15_col16, #T_688d6_row15_col24, #T_688d6_row15_col25, #T_688d6_row16_col1, #T_688d6_row16_col6, #T_688d6_row16_col7, #T_688d6_row16_col8, #T_688d6_row16_col10, #T_688d6_row16_col12, #T_688d6_row16_col15, #T_688d6_row16_col17, #T_688d6_row16_col19, #T_688d6_row16_col21, #T_688d6_row18_col0, #T_688d6_row25_col2, #T_688d6_row25_col13, #T_688d6_row25_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_688d6_row0_col3, #T_688d6_row11_col1, #T_688d6_row11_col2, #T_688d6_row11_col7, #T_688d6_row11_col12, #T_688d6_row11_col19, #T_688d6_row13_col3, #T_688d6_row18_col3, #T_688d6_row25_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_688d6_row0_col4, #T_688d6_row0_col5, #T_688d6_row0_col9, #T_688d6_row0_col14, #T_688d6_row0_col20, #T_688d6_row0_col22, #T_688d6_row0_col23, #T_688d6_row1_col4, #T_688d6_row1_col5, #T_688d6_row1_col9, #T_688d6_row1_col14, #T_688d6_row1_col20, #T_688d6_row1_col22, #T_688d6_row1_col23, #T_688d6_row2_col4, #T_688d6_row2_col5, #T_688d6_row2_col9, #T_688d6_row2_col14, #T_688d6_row2_col20, #T_688d6_row2_col22, #T_688d6_row2_col23, #T_688d6_row3_col4, #T_688d6_row3_col5, #T_688d6_row3_col9, #T_688d6_row3_col14, #T_688d6_row3_col20, #T_688d6_row3_col22, #T_688d6_row3_col23, #T_688d6_row4_col0, #T_688d6_row4_col1, #T_688d6_row4_col2, #T_688d6_row4_col3, #T_688d6_row4_col4, #T_688d6_row4_col5, #T_688d6_row4_col6, #T_688d6_row4_col7, #T_688d6_row4_col8, #T_688d6_row4_col9, #T_688d6_row4_col10, #T_688d6_row4_col11, #T_688d6_row4_col12, #T_688d6_row4_col13, #T_688d6_row4_col14, #T_688d6_row4_col15, #T_688d6_row4_col16, #T_688d6_row4_col17, #T_688d6_row4_col18, #T_688d6_row4_col19, #T_688d6_row4_col20, #T_688d6_row4_col21, #T_688d6_row4_col22, #T_688d6_row4_col23, #T_688d6_row4_col24, #T_688d6_row4_col25, #T_688d6_row5_col0, #T_688d6_row5_col1, #T_688d6_row5_col2, #T_688d6_row5_col3, #T_688d6_row5_col4, #T_688d6_row5_col5, #T_688d6_row5_col6, #T_688d6_row5_col7, #T_688d6_row5_col8, #T_688d6_row5_col9, #T_688d6_row5_col10, #T_688d6_row5_col11, #T_688d6_row5_col12, #T_688d6_row5_col13, #T_688d6_row5_col14, #T_688d6_row5_col15, #T_688d6_row5_col16, #T_688d6_row5_col17, #T_688d6_row5_col18, #T_688d6_row5_col19, #T_688d6_row5_col20, #T_688d6_row5_col21, #T_688d6_row5_col22, #T_688d6_row5_col23, #T_688d6_row5_col24, #T_688d6_row5_col25, #T_688d6_row6_col4, #T_688d6_row6_col5, #T_688d6_row6_col9, #T_688d6_row6_col14, #T_688d6_row6_col20, #T_688d6_row6_col22, #T_688d6_row6_col23, #T_688d6_row7_col4, #T_688d6_row7_col5, #T_688d6_row7_col9, #T_688d6_row7_col14, #T_688d6_row7_col20, #T_688d6_row7_col22, #T_688d6_row7_col23, #T_688d6_row8_col4, #T_688d6_row8_col5, #T_688d6_row8_col9, #T_688d6_row8_col14, #T_688d6_row8_col20, #T_688d6_row8_col22, #T_688d6_row8_col23, #T_688d6_row9_col0, #T_688d6_row9_col1, #T_688d6_row9_col2, #T_688d6_row9_col3, #T_688d6_row9_col4, #T_688d6_row9_col5, #T_688d6_row9_col6, #T_688d6_row9_col7, #T_688d6_row9_col8, #T_688d6_row9_col9, #T_688d6_row9_col10, #T_688d6_row9_col11, #T_688d6_row9_col12, #T_688d6_row9_col13, #T_688d6_row9_col14, #T_688d6_row9_col15, #T_688d6_row9_col16, #T_688d6_row9_col17, #T_688d6_row9_col18, #T_688d6_row9_col19, #T_688d6_row9_col20, #T_688d6_row9_col21, #T_688d6_row9_col22, #T_688d6_row9_col23, #T_688d6_row9_col24, #T_688d6_row9_col25, #T_688d6_row10_col4, #T_688d6_row10_col5, #T_688d6_row10_col9, #T_688d6_row10_col14, #T_688d6_row10_col20, #T_688d6_row10_col22, #T_688d6_row10_col23, #T_688d6_row11_col4, #T_688d6_row11_col5, #T_688d6_row11_col9, #T_688d6_row11_col14, #T_688d6_row11_col20, #T_688d6_row11_col22, #T_688d6_row11_col23, #T_688d6_row12_col4, #T_688d6_row12_col5, #T_688d6_row12_col9, #T_688d6_row12_col14, #T_688d6_row12_col20, #T_688d6_row12_col22, #T_688d6_row12_col23, #T_688d6_row13_col4, #T_688d6_row13_col5, #T_688d6_row13_col9, #T_688d6_row13_col14, #T_688d6_row13_col20, #T_688d6_row13_col22, #T_688d6_row13_col23, #T_688d6_row14_col0, #T_688d6_row14_col1, #T_688d6_row14_col2, #T_688d6_row14_col3, #T_688d6_row14_col4, #T_688d6_row14_col5, #T_688d6_row14_col6, #T_688d6_row14_col7, #T_688d6_row14_col8, #T_688d6_row14_col9, #T_688d6_row14_col10, #T_688d6_row14_col11, #T_688d6_row14_col12, #T_688d6_row14_col13, #T_688d6_row14_col14, #T_688d6_row14_col15, #T_688d6_row14_col16, #T_688d6_row14_col17, #T_688d6_row14_col18, #T_688d6_row14_col19, #T_688d6_row14_col20, #T_688d6_row14_col21, #T_688d6_row14_col22, #T_688d6_row14_col23, #T_688d6_row14_col24, #T_688d6_row14_col25, #T_688d6_row15_col4, #T_688d6_row15_col5, #T_688d6_row15_col9, #T_688d6_row15_col14, #T_688d6_row15_col20, #T_688d6_row15_col22, #T_688d6_row15_col23, #T_688d6_row16_col4, #T_688d6_row16_col5, #T_688d6_row16_col9, #T_6 ...

# %%
#Adding the RUL column
def add_rul(g):
    g['RUL'] = max(g['cycle']) - g['cycle']
    return g

df1 = df.groupby('engine').apply(add_rul)
df1.head()
# Out:
# /var/folders/38/nymsn4sn24d8qm6p02ymbys40000gn/T/ipykernel_46308/1596578781.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df1 = df.groupby('engine').apply(add_rul)
#           engine  cycle  altitude     TRA  mach_nr      T2     T24      T30      T50     P2  ...  \
# engine                                                                                       ...
# 1      0       1      2    0.0019 -0.0003    100.0  518.67  642.15  1591.82  1403.14  14.62  ...
#        1       1      3   -0.0043  0.0003    100.0  518.67  642.35  1587.99  1404.20  14.62  ...
#        2       1      4    0.0007  0.0000    100.0  518.67  642.35  1582.79  1401.87  14.62  ...
#        3       1      5   -0.0019 -0.0002    100.0  518.67  642.37  1582.85  1406.22  14.62  ...
#        4       1      6   -0.0043 -0.0001    100.0  518.67  642.10  1584.47  1398.37  14.62  ...
#
#               NRf      NRc     BPR  farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32  RUL
# engine
# 1      0  2388.07  8131.49  8.4318  0.03      392    2388      100.0  39.00  23.4236  190
#        1  2388.03  8133.23  8.4178  0.03      390    2388      100.0  38.95  23.3442  189
#        2  2388.08  8133.83  8.3682  0.03      392    2388      100.0  38.88  23.3739  188
#        3  2388.04  8133.80  8.4294  0.03      393    2388      100.0  38.90  23.4044  187
#        4  2388.03  8132.85  8.4108  0.03      391    2388      100.0  38.98  23.3669  186
#
# [5 rows x 27 columns]

# %%
# another way to calculate the RUL
df1['RUL2'] = 0
for engine_id in np.unique(df1.engine):
    end_of_life = np.max(df1.loc[df1['engine'] == engine_id, 'cycle'].values)
    df1.loc[df1['engine'] == engine_id, 'RUL2'] = end_of_life - df1.loc[df1['engine'] == engine_id, 'cycle']
df1.head()
df1 = df1.drop(['RUL2'], axis=1)
df1.head()
# Out:
#           engine  cycle  altitude     TRA  mach_nr      T2     T24      T30      T50     P2  ...  \
# engine                                                                                       ...
# 1      0       1      2    0.0019 -0.0003    100.0  518.67  642.15  1591.82  1403.14  14.62  ...
#        1       1      3   -0.0043  0.0003    100.0  518.67  642.35  1587.99  1404.20  14.62  ...
#        2       1      4    0.0007  0.0000    100.0  518.67  642.35  1582.79  1401.87  14.62  ...
#        3       1      5   -0.0019 -0.0002    100.0  518.67  642.37  1582.85  1406.22  14.62  ...
#        4       1      6   -0.0043 -0.0001    100.0  518.67  642.10  1584.47  1398.37  14.62  ...
#
#               NRf      NRc     BPR  farB  htBleed  Nf_dmd  PCNfR_dmd    W31      W32  RUL
# engine
# 1      0  2388.07  8131.49  8.4318  0.03      392    2388      100.0  39.00  23.4236  190
#        1  2388.03  8133.23  8.4178  0.03      390    2388      100.0  38.95  23.3442  189
#        2  2388.08  8133.83  8.3682  0.03      392    2388      100.0  38.88  23.3739  188
#        3  2388.04  8133.80  8.4294  0.03      393    2388      100.0  38.90  23.4044  187
#        4  2388.03  8132.85  8.4108  0.03      391    2388      100.0  38.98  23.3669  186
#
# [5 rows x 27 columns]

# %%
import math
import scipy.stats

# %%
y1 = df1['RUL']/400
X1 = df1.drop(['RUL', 'engine'], axis=1)/400

y_1_train = y1[df1.engine.values < 80]
y_1_test = y1[df1.engine.values >= 80]

X1_train = X1.loc[df1.engine < 80, :]
X1_test = X1.loc[df1.engine >= 80, :]

for col in X1_train.columns:
    if np.std(X1_train[col].values) != 0:
        X1_train.loc[:,col] = (X1_train[col].values - np.mean(X1_train[col].values)) / np.std(X1_train[col].values)
    else:
        X1_train.loc[:,col] = 1
for col in X1_train.columns:
    if np.std(X1_test.loc[:,col].values) != 0:
        X1_test.loc[:,col] = (X1_test[col].values - np.mean(X1_test[col].values)) / np.std(X1_test[col].values)
    else:
        X1_test.loc[:, col] = 1

# %%
from sklearn.ensemble import RandomForestRegressor

rfr = RandomForestRegressor(max_depth=3)
rfr.fit(X1_train, y_1_train)
predictions = rfr.predict(X1_test)

errors = predictions - (y_1_test)
print(np.mean(np.abs(errors))*400)
# Out:
# 36.45050121012054
